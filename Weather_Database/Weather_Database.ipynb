# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lats_lngs = zip(lats, lngs)
lats_lngs

# %%
    # Add the latitudes and longitudes to a list
coordinates = list(lats_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f'City count: {len(cities)}')
# Out:
# City count: 772

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

#check api key 
weather_api_key
# Out:
# 'e93025a42d0b55bcdec8aa2a58199c11'

# %%
# Assemble the OpenWeatherMap's API call
url="http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
#Create an empty list to hold the weather data.
city_data = []

#Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
 
    # Run API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Latitude": city_lat,
                          "Longitude": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print(city + " not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | vestmannaeyjar
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mar del plata
# Processing Record 4 of Set 1 | chokurdakh
# Processing Record 5 of Set 1 | upernavik
# Processing Record 6 of Set 1 | tuatapere
# Processing Record 7 of Set 1 | cayenne
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | karauzyak
# karauzyak not found. Skipping...
# Processing Record 10 of Set 1 | taolanaro
# taolanaro not found. Skipping...
# Processing Record 11 of Set 1 | lebu
# Processing Record 12 of Set 1 | amderma
# amderma not found. Skipping...
# Processing Record 13 of Set 1 | necochea
# Processing Record 14 of Set 1 | koulikoro
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | vaini
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | omsukchan
# Processing Record 19 of Set 1 | saskylakh
# Processing Record 20 of Set 1 | warqla
# warqla not found. Skipping...
# Processing Record 21 of Set 1 | hovd
# Processing Record 22 of Set 1 | harnosand
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | ilulissat
# Processing Record 25 of Set 1 | marcona
# marcona not found. Skipping...
# Processing Record 26 of Set 1 | pandanon
# pandanon not found. Skipping...
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | lodja
# Processing Record 29 of Set 1 | rocha
# Processing Record 30 of Set 1 | busselton
# Processing Record 31 of Set 1 | wairoa
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | pavilosta
# Processing Record 35 of Set 1 | yellowknife
# Processing Record 36 of Set 1 | kununurra
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | bissau
# Processing Record 39 of Set 1 | ostrovnoy
# Processing Record 40 of Set 1 | narsaq
# Processing Record 41 of Set 1 | komsomolskiy
# Processing Record 42 of Set 1 | punta arenas
# Processing Record 43 of Set 1 | flinders
# Processing Record 44 of Set 1 | new norfolk
# Processing Record 45 of Set 1 | tual
# Processing Record 46 of Set 1 | bambous virieux
# Processing Record 47 of Set 1 | sumen
# sumen not found. Skipping...
# Processing Record 48 of Set 1 | port macquarie
# Processing Record 49 of Set 1 | laramie
# Processing Record 50 of Set 1 | ustyuzhna
# Processing Record 1 of Set 2 | ushuaia
# Processing Record 2 of Set 2 | mashhad
# Processing Record 3 of Set 2 | georgetown
# Processing Record 4 of Set 2 | surt
# Processing Record 5 of Set 2 | guerrero negro
# Processing Record 6 of Set 2 | camabatela
# Processing Record 7 of Set 2 | qaanaaq
# Processing Record 8 of Set 2 | iqaluit
# Processing Record 9 of Set 2 | mbala
# Processing Record 10 of Set 2 | kautokeino
# Processing Record 11 of Set 2 | barentsburg
# barentsburg not found. Skipping...
# Processing Record 12 of Set 2 | louisbourg
# louisbourg not found. Skipping...
# Processing Record 13 of Set 2 | illoqqortoormiut
# illoqqortoormiut not found. Skipping...
# Processing Record 14 of Set 2 | port augusta
# Processing Record 15 of Set 2 | belushya guba
# belushya guba not found. Skipping...
# Processing Record 16 of Set 2 | ivdel
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | albany
# Processing Record 19 of Set 2 | san quintin
# Processing Record 20 of Set 2 | socol
# Processing Record 21 of Set 2 | madaba
# Processing Record 22 of Set 2 | grand gaube
# Processing Record 23 of Set 2 | mattru
# Processing Record 24 of Set 2 | luderitz
# Processing Record 25 of Set 2 | sinop
# Processing Record 26 of Set 2 | caravelas
# Processing Record 27 of Set 2 | asau
# Processing Record 28 of Set 2 | rosarito
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | hofn
# Processing Record 31 of Set 2 | dikson
# Processing Record 32 of Set 2 | codrington
# Processing Record 33 of Set 2 | acapulco
# Processing Record 34 of Set 2 | sitka
# Processing Record 35 of Set 2 | dudinka
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | udachnyy
# Processing Record 39 of Set 2 | salmon arm
# Processing Record 40 of Set 2 | taksimo
# Processing Record 41 of Set 2 | elizabeth city
# Processing Record 42 of Set 2 | lauro muller
# Processing Record 43 of Set 2 | saldanha
# Processing Record 44 of Set 2 | vao
# Processing Record 45 of Set 2 | ponta do sol
# Processing Record 46 of Set 2 | sur
# Processing Record 47 of Set 2 | belaya gora
# Processing Record 48 of Set 2 | hambantota
# Processing Record 49 of Set 2 | buala
# Processing Record 50 of Set 2 | barrow
# Processing Record 1 of Set 3 | chuy
# Processing Record 2 of Set 3 | beloha
# Processing Record 3 of Set 3 | puerto ayora
# Processing Record 4 of Set 3 | herat
# Processing Record 5 of Set 3 | santo antonio do ica
# Processing Record 6 of Set 3 | ruidoso
# Processing Record 7 of Set 3 | sakakah
# Processing Record 8 of Set 3 | hamilton
# Processing Record 9 of Set 3 | zarubino
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | mto wa mbu
# Processing Record 12 of Set 3 | atuona
# Processing Record 13 of Set 3 | west monroe
# Processing Record 14 of Set 3 | bisho
# Processing Record 15 of Set 3 | saint-philippe
# Processing Record 16 of Set 3 | tiksi
# Processing Record 17 of Set 3 | katsuura
# Processing Record 18 of Set 3 | strunino
# Processing Record 19 of Set 3 | aras
# Processing Record 20 of Set 3 | naron
# Processing Record 21 of Set 3 | gamba
# Processing Record 22 of Set 3 | hope
# Processing Record 23 of Set 3 | datong
# Processing Record 24 of Set 3 | husavik
# Processing Record 25 of Set 3 | waingapu
# Processing Record 26 of Set 3 | leningradskiy
# Processing Record 27 of Set 3 | horki
# Processing Record 28 of Set 3 | tres arroyos
# Processing Record 29 of Set 3 | mazyr
# Processing Record 30 of Set 3 | belmonte
# Processing Record 31 of Set 3 | bandarbeyla
# Processing Record 32 of Set 3 | butaritari
# Processing Record 33 of Set 3 | nikolskoye
# Processing Record 34 of Set 3 | cape town
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | touros
# Processing Record 37 of Set 3 | svetlyy
# Processing Record 38 of Set 3 | bay roberts
# Processing Record 39 of Set 3 | dawlatabad
# Processing Record 40 of Set 3 | opuwo
# Processing Record 41 of Set 3 | sampit
# Processing Record 42 of Set 3 | richards bay
# Processing Record 43 of Set 3 | yar-sale
# Processing Record 44 of Set 3 | kamskiye polyany
# Processing Record 45 of Set 3 | ancud
# Processing Record 46 of Set 3 | avarua
# Processing Record 47 of Set 3 | tsihombe
# tsihombe not found. Skipping...
# Processing Record 48 of Set 3 | waddan
# Processing Record 49 of Set 3 | bonavista
# Processing Record 50 of Set 3 | port elizabeth
# Processing Record 1 of Set 4 | broken hill
# Processing Record 2 of Set 4 | haibowan
# haibowan not found. Skipping...
# Processing Record 3 of Set 4 | alcaniz
# Processing Record 4 of Set 4 | rawson
# Processing Record 5 of Set 4 | hualmay
# Processing Record 6 of Set 4 | ewa beach
# Processing Record 7 of Set 4 | thompson
# Processing Record 8 of Set 4 | fengrun
# Processing Record 9 of Set 4 | vardo
# Processing Record 10 of Set 4 | saint george
# Processing Record 11 of Set 4 | yulin
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | khatanga
# Processing Record 14 of Set 4 | wad rawah
# Processing Record 15 of Set 4 | mopti
# Processing Record 16 of Set 4 | hermanus
# Processing Record 17 of Set 4 | lubango
# Processing Record 18 of Set 4 | deputatskiy
# Processing Record 19 of Set 4 | carnarvon
# Processing Record 20 of Set 4 | oriximina
# Processing Record 21 of Set 4 | cabo san lucas
# Processing Record 22 of Set 4 | saleaula
# saleaula not found. Skipping...
# Processing Record 23 of Set 4 | fria
# Processing Record 24 of Set 4 | port lincoln
# Processing Record 25 of Set 4 | nampa
# Processing Record 26 of Set 4 | viedma
# Processing Record 27 of Set 4 | lianran
# Processing Record 28 of Set 4 | san patricio
# Processing Record 29 of Set 4 | kapaa
# Processing Record 30 of Set 4 | trincomalee
# Processing Record 31 of Set 4 | zyryanka
# Processing Record 32 of Set 4 | provideniya
# Processing Record 33 of Set 4 | mahebourg
# Processing Record 34 of Set 4 | qasigiannguit
# Processing Record 35 of Set 4 | tura
# Processing Record 36 of Set 4 | nizhneyansk
# nizhneyansk not found. Skipping...
# Processing Record 37 of Set 4 | coahuayana
# Processing Record 38 of Set 4 | castro
# Processing Record 39 of Set 4 | san francisco
# Processing Record 40 of Set 4 | lisala
# Processing Record 41 of Set 4 | la palma
# Processing Record 42 of Set 4 | taoudenni
# Processing Record 43 of Set 4 | bundaberg
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | palana
# Processing Record 46 of Set 4 | pergamino
# Processing Record 47 of Set 4 | villa carlos paz
# Processing Record 48 of Set 4 | labuhan
# Processing Record 49 of Set 4 | balabac
# Processing Record 50 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | meulaboh
# Processing Record 2 of Set 5 | kajaani
# Processing Record 3 of Set 5 | lata
# Processing Record 4 of Set 5 | nueve de julio
# Processing Record 5 of Set 5 | namibe
# Processing Record 6 of Set 5 | naifaru
# Processing Record 7 of Set 5 | grand centre
# grand centre not found. Skipping...
# Processing Record 8 of Set 5 | mandalgovi
# Processing Record 9 of Set 5 | grand forks
# Processing Record 10 of Set 5 | prince rupert
# Processing Record 11 of Set 5 | tautira
# Processing Record 12 of Set 5 | merauke
# Processing Record 13 of Set 5 | hasaki
# Processing Record 14 of Set 5 | smolenka
# Processing Record 15 of Set 5 | tasiilaq
# Processing Record 16 of Set 5 | whitehorse
# Processing Record 17 of Set 5 | astoria
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | elmira
# Processing Record 20 of Set 5 | salinopolis
# Processing Record 21 of Set 5 | tawang
# Processing Record 22 of Set 5 | kaeo
# Processing Record 23 of Set 5 | sao joao da barra
# Processing Record 24 of Set 5 | tazovskiy
# Processing Record 25 of Set 5 | camacha
# Processing Record 26 of Set 5 | natal
# Processing Record 27 of Set 5 | bahia de caraquez
# Processing Record 28 of Set 5 | arraial do cabo
# Processing Record 29 of Set 5 | savannah bight
# Processing Record 30 of Set 5 | stuttgart
# Processing Record 31 of Set 5 | port keats
# Processing Record 32 of Set 5 | makurdi
# Processing Record 33 of Set 5 | escanaba
# Processing Record 34 of Set 5 | saint-augustin
# Processing Record 35 of Set 5 | samalaeulu
# samalaeulu not found. Skipping...
# Processing Record 36 of Set 5 | ossora
# Processing Record 37 of Set 5 | nguiu
# nguiu not found. Skipping...
# Processing Record 38 of Set 5 | kazerun
# Processing Record 39 of Set 5 | isangel
# Processing Record 40 of Set 5 | imbituba
# Processing Record 41 of Set 5 | andros town
# Processing Record 42 of Set 5 | birao
# Processing Record 43 of Set 5 | byron bay
# Processing Record 44 of Set 5 | karaul
# karaul not found. Skipping...
# Processing Record 45 of Set 5 | port blair
# Processing Record 46 of Set 5 | napier
# Processing Record 47 of Set 5 | christchurch
# Processing Record 48 of Set 5 | lavrentiya
# Processing Record 49 of Set 5 | sao filipe
# Processing Record 50 of Set 5 | panguna
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | ribeira grande
# Processing Record 3 of Set 6 | saint-georges
# Processing Record 4 of Set 6 | sioux lookout
# Processing Record 5 of Set 6 | charlestown
# Processing Record 6 of Set 6 | alofi
# Processing Record 7 of Set 6 | bethel
# Processing Record 8 of Set 6 | milas
# Processing Record 9 of Set 6 | sonoita
# Processing Record 10 of Set 6 | jumla
# Processing Record 11 of Set 6 | urdzhar
# urdzhar not found. Skipping...
# Processing Record 12 of Set 6 | wollongong
# Processing Record 13 of Set 6 | eidfjord
# Processing Record 14 of Set 6 | shahreza
# Processing Record 15 of Set 6 | wanganui
# Processing Record 16 of Set 6 | khasan
# Processing Record 17 of Set 6 | faanui
# Processing Record 18 of Set 6 | chincha alta
# Processing Record 19 of Set 6 | puerto carreno
# Processing Record 20 of Set 6 | antofagasta
# Processing Record 21 of Set 6 | ladario
# Processing Record 22 of Set 6 | mezhdurechensk
# Processing Record 23 of Set 6 | westport
# Processing Record 24 of Set 6 | luau
# Processing Record 25 of Set 6 | vaitupu
# vaitupu not found. Skipping...
# Processing Record 26 of Set 6 | henties bay
# Processing Record 27 of Set 6 | monrovia
# Processing Record 28 of Set 6 | bolungarvik
# bolungarvik not found. Skipping...
# Processing Record 29 of Set 6 | badgam
# badgam not found. Skipping...
# Processing Record 30 of Set 6 | marawi
# Processing Record 31 of Set 6 | phan rang
# phan rang not found. Skipping...
# Processing Record 32 of Set 6 | cervo
# Processing Record 33 of Set 6 | tuburan
# Processing Record 34 of Set 6 | cidreira
# Processing Record 35 of Set 6 | pagudpud
# Processing Record 36 of Set 6 | okha
# Processing Record 37 of Set 6 | souillac
# Processing Record 38 of Set 6 | maturin
# Processing Record 39 of Set 6 | ahuimanu
# Processing Record 40 of Set 6 | port-gentil
# Processing Record 41 of Set 6 | sandnessjoen
# Processing Record 42 of Set 6 | daru
# Processing Record 43 of Set 6 | makakilo city
# Processing Record 44 of Set 6 | ngunguru
# Processing Record 45 of Set 6 | samusu
# samusu not found. Skipping...
# Processing Record 46 of Set 6 | lorengau
# Processing Record 47 of Set 6 | sapa
# Processing Record 48 of Set 6 | poum
# Processing Record 49 of Set 6 | qusar
# Processing Record 50 of Set 6 | kenai
# Processing Record 1 of Set 7 | ozgon
# ozgon not found. Skipping...
# Processing Record 2 of Set 7 | hunza
# hunza not found. Skipping...
# Processing Record 3 of Set 7 | isla mujeres
# Processing Record 4 of Set 7 | severo-kurilsk
# Processing Record 5 of Set 7 | half moon bay
# Processing Record 6 of Set 7 | mrirt
# mrirt not found. Skipping...
# Processing Record 7 of Set 7 | huarmey
# Processing Record 8 of Set 7 | grand river south east
# grand river south east not found. Skipping...
# Processing Record 9 of Set 7 | san carlos de bariloche
# Processing Record 10 of Set 7 | esso
# Processing Record 11 of Set 7 | ibra
# Processing Record 12 of Set 7 | flin flon
# Processing Record 13 of Set 7 | young
# Processing Record 14 of Set 7 | enshi
# Processing Record 15 of Set 7 | kaitangata
# Processing Record 16 of Set 7 | kulhudhuffushi
# Processing Record 17 of Set 7 | los amates
# Processing Record 18 of Set 7 | general roca
# Processing Record 19 of Set 7 | aklavik
# Processing Record 20 of Set 7 | el campo
# Processing Record 21 of Set 7 | fairbanks
# Processing Record 22 of Set 7 | te anau
# Processing Record 23 of Set 7 | longyearbyen
# Processing Record 24 of Set 7 | havre-saint-pierre
# Processing Record 25 of Set 7 | santa rosa
# Processing Record 26 of Set 7 | bairiki
# Processing Record 27 of Set 7 | jawhar
# Processing Record 28 of Set 7 | sawakin
# Processing Record 29 of Set 7 | sembe
# Processing Record 30 of Set 7 | mezen
# Processing Record 31 of Set 7 | muzhi
# Processing Record 32 of Set 7 | cravo norte
# Processing Record 33 of Set 7 | shitanjing
# Processing Record 34 of Set 7 | port hawkesbury
# Processing Record 35 of Set 7 | safranbolu
# Processing Record 36 of Set 7 | zhigalovo
# Processing Record 37 of Set 7 | lasa
# Processing Record 38 of Set 7 | siedlce
# Processing Record 39 of Set 7 | puerto escondido
# Processing Record 40 of Set 7 | shache
# Processing Record 41 of Set 7 | suntar
# Processing Record 42 of Set 7 | buraydah
# Processing Record 43 of Set 7 | khandyga
# Processing Record 44 of Set 7 | tarut
# Processing Record 45 of Set 7 | alexandria
# Processing Record 46 of Set 7 | wamba
# Processing Record 47 of Set 7 | fort nelson
# Processing Record 48 of Set 7 | burnie
# Processing Record 49 of Set 7 | port hardy
# Processing Record 50 of Set 7 | san-pedro
# Processing Record 1 of Set 8 | juifang
# juifang not found. Skipping...
# Processing Record 2 of Set 8 | muros
# Processing Record 3 of Set 8 | kavaratti
# Processing Record 4 of Set 8 | nizhniy kuranakh
# Processing Record 5 of Set 8 | talnakh
# Processing Record 6 of Set 8 | hithadhoo
# Processing Record 7 of Set 8 | manjo
# Processing Record 8 of Set 8 | el tigre
# Processing Record 9 of Set 8 | pahrump
# Processing Record 10 of Set 8 | kidal
# Processing Record 11 of Set 8 | balestrand
# Processing Record 12 of Set 8 | kruisfontein
# Processing Record 13 of Set 8 | turukhansk
# Processing Record 14 of Set 8 | miraflores
# Processing Record 15 of Set 8 | haverfordwest
# Processing Record 16 of Set 8 | cherskiy
# Processing Record 17 of Set 8 | bedesa
# Processing Record 18 of Set 8 | wahran
# wahran not found. Skipping...
# Processing Record 19 of Set 8 | port moresby
# Processing Record 20 of Set 8 | college
# Processing Record 21 of Set 8 | salinas
# Processing Record 22 of Set 8 | araouane
# Processing Record 23 of Set 8 | missoula
# Processing Record 24 of Set 8 | rio muerto
# Processing Record 25 of Set 8 | talaya
# Processing Record 26 of Set 8 | vigrestad
# Processing Record 27 of Set 8 | kilosa
# Processing Record 28 of Set 8 | madang
# Processing Record 29 of Set 8 | sokur
# Processing Record 30 of Set 8 | aswan
# Processing Record 31 of Set 8 | vicuna
# Processing Record 32 of Set 8 | ust-omchug
# Processing Record 33 of Set 8 | kodyma
# Processing Record 34 of Set 8 | nakamura
# Processing Record 35 of Set 8 | atambua
# Processing Record 36 of Set 8 | dmytrivka
# Processing Record 37 of Set 8 | alangayam
# Processing Record 38 of Set 8 | newcastle
# Processing Record 39 of Set 8 | abeche
# Processing Record 40 of Set 8 | quatre cocos
# Processing Record 41 of Set 8 | kushmurun
# Processing Record 42 of Set 8 | anchorage
# Processing Record 43 of Set 8 | umm lajj
# Processing Record 44 of Set 8 | simbahan
# Processing Record 45 of Set 8 | liniere
# liniere not found. Skipping...
# Processing Record 46 of Set 8 | cabedelo
# Processing Record 47 of Set 8 | beyneu
# Processing Record 48 of Set 8 | vacha
# Processing Record 49 of Set 8 | yamethin
# Processing Record 50 of Set 8 | mackay
# Processing Record 1 of Set 9 | wuda
# Processing Record 2 of Set 9 | ardistan
# ardistan not found. Skipping...
# Processing Record 3 of Set 9 | harper
# Processing Record 4 of Set 9 | sorland
# Processing Record 5 of Set 9 | linshui
# Processing Record 6 of Set 9 | roebourne
# Processing Record 7 of Set 9 | zemlyansk
# Processing Record 8 of Set 9 | tabialan
# tabialan not found. Skipping...
# Processing Record 9 of Set 9 | aflu
# aflu not found. Skipping...
# Processing Record 10 of Set 9 | dali
# Processing Record 11 of Set 9 | alotau
# alotau not found. Skipping...
# Processing Record 12 of Set 9 | yerofey pavlovich
# Processing Record 13 of Set 9 | okato
# Processing Record 14 of Set 9 | basoko
# Processing Record 15 of Set 9 | kincardine
# Processing Record 16 of Set 9 | san cristobal
# Processing Record 17 of Set 9 | sri aman
# Processing Record 18 of Set 9 | torbay
# Processing Record 19 of Set 9 | kizner
# Processing Record 20 of Set 9 | trairi
# Processing Record 21 of Set 9 | caratinga
# Processing Record 22 of Set 9 | barra do garcas
# Processing Record 23 of Set 9 | linxia
# Processing Record 24 of Set 9 | vestmanna
# Processing Record 25 of Set 9 | mogadishu
# Processing Record 26 of Set 9 | avera
# Processing Record 27 of Set 9 | diego de almagro
# Processing Record 28 of Set 9 | kizilskoye
# Processing Record 29 of Set 9 | wau
# Processing Record 30 of Set 9 | eydhafushi
# Processing Record 31 of Set 9 | dumas
# Processing Record 32 of Set 9 | vanavara
# Processing Record 33 of Set 9 | vestbygda
# vestbygda not found. Skipping...
# Processing Record 34 of Set 9 | alta
# Processing Record 35 of Set 9 | bakel
# Processing Record 36 of Set 9 | soe
# Processing Record 37 of Set 9 | ulaangom
# Processing Record 38 of Set 9 | hanzhong
# Processing Record 39 of Set 9 | pevek
# Processing Record 40 of Set 9 | kandrian
# Processing Record 41 of Set 9 | thunder bay
# Processing Record 42 of Set 9 | yerbogachen
# Processing Record 43 of Set 9 | lompoc
# Processing Record 44 of Set 9 | ruatoria
# ruatoria not found. Skipping...
# Processing Record 45 of Set 9 | mys shmidta
# mys shmidta not found. Skipping...
# Processing Record 46 of Set 9 | asfi
# Processing Record 47 of Set 9 | leh
# Processing Record 48 of Set 9 | san ignacio
# Processing Record 49 of Set 9 | hami
# Processing Record 50 of Set 9 | chumikan
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | nanortalik
# Processing Record 3 of Set 10 | puri
# Processing Record 4 of Set 10 | enugu
# Processing Record 5 of Set 10 | hobyo
# Processing Record 6 of Set 10 | sobolevo
# Processing Record 7 of Set 10 | honiara
# Processing Record 8 of Set 10 | mahajanga
# Processing Record 9 of Set 10 | palu
# Processing Record 10 of Set 10 | kahului
# Processing Record 11 of Set 10 | saint-pierre
# Processing Record 12 of Set 10 | kingisepp
# Processing Record 13 of Set 10 | tartagal
# Processing Record 14 of Set 10 | vaitape
# Processing Record 15 of Set 10 | tommot
# Processing Record 16 of Set 10 | moron
# Processing Record 17 of Set 10 | kodiak
# Processing Record 18 of Set 10 | alyangula
# Processing Record 19 of Set 10 | tashtagol
# Processing Record 20 of Set 10 | santa ana
# Processing Record 21 of Set 10 | attawapiskat
# attawapiskat not found. Skipping...
# Processing Record 22 of Set 10 | banjar
# Processing Record 23 of Set 10 | bapatla
# Processing Record 24 of Set 10 | akyab
# Processing Record 25 of Set 10 | mehamn
# Processing Record 26 of Set 10 | tadine
# Processing Record 27 of Set 10 | kavieng
# Processing Record 28 of Set 10 | ukiah
# Processing Record 29 of Set 10 | tateyama
# Processing Record 30 of Set 10 | faya
# Processing Record 31 of Set 10 | harda
# Processing Record 32 of Set 10 | karakulino
# Processing Record 33 of Set 10 | jacareacanga
# Processing Record 34 of Set 10 | la peca
# Processing Record 35 of Set 10 | coquimbo
# Processing Record 36 of Set 10 | boysun
# Processing Record 37 of Set 10 | kuybyshevo
# Processing Record 38 of Set 10 | porto santo
# Processing Record 39 of Set 10 | lingao
# Processing Record 40 of Set 10 | nova praha
# Processing Record 41 of Set 10 | panzhihua
# Processing Record 42 of Set 10 | maldonado
# Processing Record 43 of Set 10 | torres
# Processing Record 44 of Set 10 | dunedin
# Processing Record 45 of Set 10 | santa cruz
# Processing Record 46 of Set 10 | matagami
# Processing Record 47 of Set 10 | rahimatpur
# Processing Record 48 of Set 10 | sola
# Processing Record 49 of Set 10 | hashtrud
# Processing Record 50 of Set 10 | tiznit
# Processing Record 1 of Set 11 | mount gambier
# Processing Record 2 of Set 11 | chontalpa
# Processing Record 3 of Set 11 | tocopilla
# Processing Record 4 of Set 11 | halalo
# halalo not found. Skipping...
# Processing Record 5 of Set 11 | shimoda
# Processing Record 6 of Set 11 | teguldet
# Processing Record 7 of Set 11 | naryan-mar
# Processing Record 8 of Set 11 | sechura
# Processing Record 9 of Set 11 | saint anthony
# Processing Record 10 of Set 11 | saurimo
# Processing Record 11 of Set 11 | ozernovskiy
# Processing Record 12 of Set 11 | gizo
# Processing Record 13 of Set 11 | haines junction
# Processing Record 14 of Set 11 | dinahican
# Processing Record 15 of Set 11 | puerto princesa
# Processing Record 16 of Set 11 | ha giang
# Processing Record 17 of Set 11 | russell
# Processing Record 18 of Set 11 | pepingen
# Processing Record 19 of Set 11 | lazaro cardenas
# Processing Record 20 of Set 11 | sijunjung
# Processing Record 21 of Set 11 | amot
# Processing Record 22 of Set 11 | kendal
# Processing Record 23 of Set 11 | bolshaya martynovka
# Processing Record 24 of Set 11 | tahoua
# Processing Record 25 of Set 11 | nagorsk
# Processing Record 26 of Set 11 | santa maria
# Processing Record 27 of Set 11 | axim
# Processing Record 28 of Set 11 | coos bay
# Processing Record 29 of Set 11 | sept-iles
# Processing Record 30 of Set 11 | van buren
# Processing Record 31 of Set 11 | koshurnikovo
# Processing Record 32 of Set 11 | beya
# Processing Record 33 of Set 11 | ndele
# Processing Record 34 of Set 11 | ahipara
# Processing Record 35 of Set 11 | laguna
# Processing Record 36 of Set 11 | puerto madryn
# Processing Record 37 of Set 11 | stillwater
# Processing Record 38 of Set 11 | mutoko
# Processing Record 39 of Set 11 | guiong
# Processing Record 40 of Set 11 | upata
# Processing Record 41 of Set 11 | collie
# Processing Record 42 of Set 11 | clyde river
# Processing Record 43 of Set 11 | kingman
# Processing Record 44 of Set 11 | namatanai
# Processing Record 45 of Set 11 | da nang
# Processing Record 46 of Set 11 | aporawan
# aporawan not found. Skipping...
# Processing Record 47 of Set 11 | ust-kuyga
# Processing Record 48 of Set 11 | oistins
# Processing Record 49 of Set 11 | ust-kamchatsk
# ust-kamchatsk not found. Skipping...
# Processing Record 50 of Set 11 | berlevag
# Processing Record 1 of Set 12 | esperance
# Processing Record 2 of Set 12 | meadow lake
# Processing Record 3 of Set 12 | santa luzia
# Processing Record 4 of Set 12 | dongsheng
# Processing Record 5 of Set 12 | igarka
# Processing Record 6 of Set 12 | kichmengskiy gorodok
# Processing Record 7 of Set 12 | seoul
# Processing Record 8 of Set 12 | nicoya
# Processing Record 9 of Set 12 | colesberg
# Processing Record 10 of Set 12 | dzhusaly
# dzhusaly not found. Skipping...
# Processing Record 11 of Set 12 | champerico
# Processing Record 12 of Set 12 | la asuncion
# Processing Record 13 of Set 12 | ciudad ojeda
# Processing Record 14 of Set 12 | galgani
# galgani not found. Skipping...
# Processing Record 15 of Set 12 | ribas do rio pardo
# Processing Record 16 of Set 12 | kintinku
# Processing Record 17 of Set 12 | ginda
# Processing Record 18 of Set 12 | nara
# Processing Record 19 of Set 12 | maceio
# Processing Record 20 of Set 12 | tessalit
# Processing Record 21 of Set 12 | raudeberg
# Processing Record 22 of Set 12 | plettenberg bay
# Processing Record 23 of Set 12 | mayumba
# Processing Record 24 of Set 12 | coolum beach
# Processing Record 25 of Set 12 | kindu
# Processing Record 26 of Set 12 | ternate
# Processing Record 27 of Set 12 | bukama
# Processing Record 28 of Set 12 | kazalinsk
# kazalinsk not found. Skipping...
# Processing Record 29 of Set 12 | kathu
# Processing Record 30 of Set 12 | ayan
# Processing Record 31 of Set 12 | kabinda
# Processing Record 32 of Set 12 | trinidad
# Processing Record 33 of Set 12 | beira
# Processing Record 34 of Set 12 | tovarkovskiy
# Processing Record 35 of Set 12 | alta floresta
# Processing Record 36 of Set 12 | dzhuryn
# Processing Record 37 of Set 12 | matara
# Processing Record 38 of Set 12 | marovoay
# Processing Record 39 of Set 12 | geilo
# Processing Record 40 of Set 12 | pangai
# Processing Record 41 of Set 12 | pasni
# Processing Record 42 of Set 12 | caborca
# Processing Record 43 of Set 12 | balkhash
# Processing Record 44 of Set 12 | dzhebariki-khaya
# Processing Record 45 of Set 12 | kudahuvadhoo
# Processing Record 46 of Set 12 | impfondo
# Processing Record 47 of Set 12 | anadyr
# Processing Record 48 of Set 12 | labytnangi
# Processing Record 49 of Set 12 | bud
# Processing Record 50 of Set 12 | alice springs
# Processing Record 1 of Set 13 | adrar
# Processing Record 2 of Set 13 | bairnsdale
# Processing Record 3 of Set 13 | chapais
# Processing Record 4 of Set 13 | camana
# Processing Record 5 of Set 13 | zuya
# Processing Record 6 of Set 13 | noyabrsk
# Processing Record 7 of Set 13 | vila velha
# Processing Record 8 of Set 13 | boa vista
# Processing Record 9 of Set 13 | oktyabrskoye
# Processing Record 10 of Set 13 | tawkar
# tawkar not found. Skipping...
# Processing Record 11 of Set 13 | sabzevar
# Processing Record 12 of Set 13 | port hedland
# Processing Record 13 of Set 13 | libertador general san martin
# Processing Record 14 of Set 13 | bara
# Processing Record 15 of Set 13 | gat
# Processing Record 16 of Set 13 | liberty
# Processing Record 17 of Set 13 | picota
# Processing Record 18 of Set 13 | palembang
# Processing Record 19 of Set 13 | arlit
# Processing Record 20 of Set 13 | deh rawud
# deh rawud not found. Skipping...
# Processing Record 21 of Set 13 | putai
# Processing Record 22 of Set 13 | batemans bay
# Processing Record 23 of Set 13 | vitim
# Processing Record 24 of Set 13 | wanning
# Processing Record 25 of Set 13 | luchegorsk
# Processing Record 26 of Set 13 | ixtapa
# Processing Record 27 of Set 13 | nemuro
# Processing Record 28 of Set 13 | vanimo
# Processing Record 29 of Set 13 | fraserburgh
# Processing Record 30 of Set 13 | pechora
# Processing Record 31 of Set 13 | novyy urengoy
# Processing Record 32 of Set 13 | broome
# Processing Record 33 of Set 13 | kamogawa
# Processing Record 34 of Set 13 | cap-aux-meules
# Processing Record 35 of Set 13 | fortuna
# Processing Record 36 of Set 13 | morros
# Processing Record 37 of Set 13 | guaraniacu
# Processing Record 38 of Set 13 | ozinki
# Processing Record 39 of Set 13 | channel-port aux basques
# Processing Record 40 of Set 13 | soyo
# Processing Record 41 of Set 13 | tumannyy
# tumannyy not found. Skipping...
# Processing Record 42 of Set 13 | ville-marie
# Processing Record 43 of Set 13 | comodoro rivadavia
# Processing Record 44 of Set 13 | tigzirt
# Processing Record 45 of Set 13 | barga
# Processing Record 46 of Set 13 | loding
# Processing Record 47 of Set 13 | macherla
# Processing Record 48 of Set 13 | pontianak
# Processing Record 49 of Set 13 | inhambane
# Processing Record 50 of Set 13 | maymyo
# Processing Record 1 of Set 14 | skelleftea
# Processing Record 2 of Set 14 | muzaffarabad
# Processing Record 3 of Set 14 | key west
# Processing Record 4 of Set 14 | wajima
# Processing Record 5 of Set 14 | guaruja
# Processing Record 6 of Set 14 | basco
# Processing Record 7 of Set 14 | urengoy
# Processing Record 8 of Set 14 | luena
# Processing Record 9 of Set 14 | palmas de monte alto
# Processing Record 10 of Set 14 | svetlaya
# Processing Record 11 of Set 14 | nam tha
# nam tha not found. Skipping...
# Processing Record 12 of Set 14 | boende
# Processing Record 13 of Set 14 | yasnyy
# Processing Record 14 of Set 14 | cabatuan
# Processing Record 15 of Set 14 | glace bay
# Processing Record 16 of Set 14 | kolodeznyy
# Processing Record 17 of Set 14 | zhanaozen
# Processing Record 18 of Set 14 | constitucion
# Processing Record 19 of Set 14 | gravdal
# Processing Record 20 of Set 14 | kharp
# Processing Record 21 of Set 14 | abu jubayhah
# abu jubayhah not found. Skipping...
# Processing Record 22 of Set 14 | murakami
# Processing Record 23 of Set 14 | mount isa
# Processing Record 24 of Set 14 | mossendjo
# Processing Record 25 of Set 14 | les cayes
# Processing Record 26 of Set 14 | menongue
# Processing Record 27 of Set 14 | utiroa
# utiroa not found. Skipping...
# Processing Record 28 of Set 14 | sault sainte marie
# Processing Record 29 of Set 14 | airai
# Processing Record 30 of Set 14 | issoudun
# Processing Record 31 of Set 14 | dreznica
# Processing Record 32 of Set 14 | doctor pedro p. pena
# doctor pedro p. pena not found. Skipping...
# Processing Record 33 of Set 14 | haimen
# Processing Record 34 of Set 14 | evensk
# Processing Record 35 of Set 14 | tarko-sale
# Processing Record 36 of Set 14 | san
# Processing Record 37 of Set 14 | fare
# Processing Record 38 of Set 14 | grindavik
# Processing Record 39 of Set 14 | khash
# Processing Record 40 of Set 14 | hearst
# Processing Record 41 of Set 14 | port shepstone
# Processing Record 42 of Set 14 | sal rei
# Processing Record 43 of Set 14 | san jeronimo
# Processing Record 44 of Set 14 | kirakira
# Processing Record 45 of Set 14 | rampur hat
# Processing Record 46 of Set 14 | ambilobe
# Processing Record 47 of Set 14 | garhi khairo
# Processing Record 48 of Set 14 | villa union
# Processing Record 49 of Set 14 | praia da vitoria
# Processing Record 50 of Set 14 | nome
# Processing Record 1 of Set 15 | green river
# Processing Record 2 of Set 15 | presidente medici
# Processing Record 3 of Set 15 | grasten
# Processing Record 4 of Set 15 | kamenka
# Processing Record 5 of Set 15 | shitkino
# Processing Record 6 of Set 15 | paamiut
# Processing Record 7 of Set 15 | ponta delgada
# Processing Record 8 of Set 15 | kanniyakumari
# Processing Record 9 of Set 15 | grand island
# Processing Record 10 of Set 15 | tilichiki
# Processing Record 11 of Set 15 | nizwa
# Processing Record 12 of Set 15 | gazanjyk
# Processing Record 13 of Set 15 | qaqortoq
# Processing Record 14 of Set 15 | sumbe
# Processing Record 15 of Set 15 | san marcos
# Processing Record 16 of Set 15 | konakovo
# Processing Record 17 of Set 15 | pagondas
# pagondas not found. Skipping...
# Processing Record 18 of Set 15 | piacabucu
# Processing Record 19 of Set 15 | cafarnaum
# Processing Record 20 of Set 15 | vila franca do campo
# Processing Record 21 of Set 15 | khani
# Processing Record 22 of Set 15 | kamenskoye
# kamenskoye not found. Skipping...
# Processing Record 23 of Set 15 | luganville
# Processing Record 24 of Set 15 | bambanglipuro
# Processing Record 25 of Set 15 | pacific grove
# Processing Record 26 of Set 15 | superior
# Processing Record 27 of Set 15 | abastumani
# Processing Record 28 of Set 15 | salalah
# Processing Record 29 of Set 15 | plastun
# Processing Record 30 of Set 15 | catamarca
# Processing Record 31 of Set 15 | buin
# Processing Record 32 of Set 15 | kalmunai
# Processing Record 33 of Set 15 | rio grande
# Processing Record 34 of Set 15 | inuvik
# Processing Record 35 of Set 15 | barentu
# Processing Record 36 of Set 15 | melo
# Processing Record 37 of Set 15 | stamsund
# stamsund not found. Skipping...
# Processing Record 38 of Set 15 | macia
# Processing Record 39 of Set 15 | pathein
# Processing Record 40 of Set 15 | kampot
# Processing Record 41 of Set 15 | barbar
# barbar not found. Skipping...
# Processing Record 42 of Set 15 | okhotsk
# Processing Record 43 of Set 15 | manono
# Processing Record 44 of Set 15 | altay
# Processing Record 45 of Set 15 | fallon
# Processing Record 46 of Set 15 | price
# Processing Record 47 of Set 15 | klaksvik
# Processing Record 48 of Set 15 | wilmington
# Processing Record 49 of Set 15 | sangmelima
# Processing Record 50 of Set 15 | mandurah
# Processing Record 1 of Set 16 | katangli
# Processing Record 2 of Set 16 | claveria
# Processing Record 3 of Set 16 | margate
# Processing Record 4 of Set 16 | galle
# Processing Record 5 of Set 16 | bushehr
# Processing Record 6 of Set 16 | solnechnyy
# Processing Record 7 of Set 16 | camacupa
# Processing Record 8 of Set 16 | lakatoro
# Processing Record 9 of Set 16 | ostersund
# Processing Record 10 of Set 16 | sovetskiy
# Processing Record 11 of Set 16 | usakos
# Processing Record 12 of Set 16 | adra
# Processing Record 13 of Set 16 | nishihara
# Processing Record 14 of Set 16 | kommunar
# Processing Record 15 of Set 16 | lolua
# lolua not found. Skipping...
# Processing Record 16 of Set 16 | matay
# Processing Record 17 of Set 16 | shawnee
# Processing Record 18 of Set 16 | alamor
# Processing Record 19 of Set 16 | sungaipenuh
# Processing Record 20 of Set 16 | umm ruwabah
# umm ruwabah not found. Skipping...
# Processing Record 21 of Set 16 | eenhana
# Processing Record 22 of Set 16 | venado tuerto
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
print(len(city_data))
# Out:
# 713

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Vestmannaeyjar  63.4427  -20.2734     43.83        73         100
# 1           Rikitea -23.1203 -134.9692     71.02        69          98
# 2     Mar Del Plata -38.0023  -57.5575     60.82        93         100
# 3        Chokurdakh  70.6333  147.9167     15.67        93         100
# 4         Upernavik  72.7868  -56.1549     16.68        72          88
# ..              ...      ...       ...       ...       ...         ...
# 708         Shawnee  39.0500  -95.7669     62.85        55          87
# 709          Alamor  -4.0181  -80.0197     61.20        72         100
# 710     Sungaipenuh  -2.0833  101.3833     76.44        68         100
# 711         Eenhana -17.4667   16.3333     72.19        38          55
# 712   Venado Tuerto -33.7456  -61.9688     62.76        72           1
#
#      Wind Speed Country Current Description                 Date
# 0          5.08      IS     overcast clouds  2022-10-21 02:36:48
# 1         20.11      PF     overcast clouds  2022-10-21 02:36:24
# 2         12.66      AR     overcast clouds  2022-10-21 02:36:48
# 3         18.32      RU          light snow  2022-10-21 02:36:49
# 4          7.09      GL     overcast clouds  2022-10-21 02:36:49
# ..          ...     ...                 ...                  ...
# 708        1.01      US     overcast clouds  2022-10-21 02:56:30
# 709        2.06      EC     overcast clouds  2022-10-21 02:56:30
# 710        3.67      ID     overcast clouds  2022-10-21 02:56:31
# 711        4.41      NA       broken clouds  2022-10-21 02:52:51
# 712        8.41      AR           clear sky  2022-10-21 02:56:32
#
# [713 rows x 10 columns]

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description', 'Date'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"

column_list = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]

# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[column_list]

# Display sample data
city_data_df
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0    Vestmannaeyjar      IS  63.4427  -20.2734     43.83        73
# 1           Rikitea      PF -23.1203 -134.9692     71.02        69
# 2     Mar Del Plata      AR -38.0023  -57.5575     60.82        93
# 3        Chokurdakh      RU  70.6333  147.9167     15.67        93
# 4         Upernavik      GL  72.7868  -56.1549     16.68        72
# ..              ...     ...      ...       ...       ...       ...
# 708         Shawnee      US  39.0500  -95.7669     62.85        55
# 709          Alamor      EC  -4.0181  -80.0197     61.20        72
# 710     Sungaipenuh      ID  -2.0833  101.3833     76.44        68
# 711         Eenhana      NA -17.4667   16.3333     72.19        38
# 712   Venado Tuerto      AR -33.7456  -61.9688     62.76        72
#
#      Cloudiness  Wind Speed Current Description
# 0           100        5.08     overcast clouds
# 1            98       20.11     overcast clouds
# 2           100       12.66     overcast clouds
# 3           100       18.32          light snow
# 4            88        7.09     overcast clouds
# ..          ...         ...                 ...
# 708          87        1.01     overcast clouds
# 709         100        2.06     overcast clouds
# 710         100        3.67     overcast clouds
# 711          55        4.41       broken clouds
# 712           1        8.41           clear sky
#
# [713 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
